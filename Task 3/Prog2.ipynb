# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
df=pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import numpy as np
X=np.array([df['SepalLengthCm'],df['SepalWidthCm'],
   df['PetalLengthCm'],df['PetalWidthCm']])
X=X.T

# %%
X.shape
# Out:
# (150, 4)

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,16):
    kmeans = KMeans(n_clusters=i, random_state=0).fit(X)
    wcss.append(kmeans.inertia_)

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14)
plt.figure(figsize=(20,10))
plt.xlabel('Number of clusters',fontsize=18)
plt.ylabel('Within Cluster Sum of Squares',fontsize=18)
plt.title('The Elbow Curve Method',fontsize=20)
plt.plot(wcss)
my_xticks=range(1,16)
plt.grid()
frequency = 1
plt.xticks(my_xticks[::frequency], my_xticks[::frequency])
plt.show()

# %% [markdown]
# ## From the elbow curve it is clear that optimal number of clusters is 3.
